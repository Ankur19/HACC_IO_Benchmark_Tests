# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/home/asaikia/Downloads/HACC_IO_Benchmark_Tests'

# %%
os.listdir(".")
# Out:
# ['bindMountResults.csv',
#  'testhacc_open_close.o',
#  'testhacc_open_close.cc',
#  'restartio_glean.h',
#  'volumeResults',
#  'bindMountResults',
#  'testhacc_printinfo.cc',
#  '.git',
#  'localResults.csv',
#  'volumeResults.csv',
#  'haccScript.sh',
#  'hacc_io',
#  'Untitled.ipynb',
#  'testhacc_io_read.o',
#  'README.md',
#  'glean_util_printmessage.h',
#  'LICENSE',
#  '.ipynb_checkpoints',
#  'hacc_io_write',
#  'restartio_glean.cc',
#  'hacc_io_read',
#  'results',
#  'testhacc_printinfo.o',
#  'testhacc_io.cc',
#  'hacc_open_close',
#  'Makefile',
#  'localResults',
#  'testhacc_io_write.o',
#  'processResults.py',
#  'restartio_glean.o',
#  'hacc_printinfo',
#  'testhacc_io.o']

# %%
df_local = pd.read_csv('localResults.csv', index_col=0)
df_volume = pd.read_csv('volumeResults.csv', index_col=0)
df_bind = pd.read_csv('bindMountResults.csv', index_col=0)

# %%
df_local
# Out:
#     Bandwidth         Size    MaxTime ReadWrite  NumParticles  NumProcesses
# 0    2031.280     63165824   0.029656     Write       1000000             1
# 1    3561.650     63165824   0.016913      Read       1000000             1
# 2    3185.650    126331648   0.037819     Write       1000000             2
# 3    6597.990    126331648   0.018260      Read       1000000             2
# 4    4775.580    189497472   0.037842     Write       1000000             3
# 5    8796.350    189497472   0.020545      Read       1000000             3
# 6    6038.180    252663296   0.039906     Write       1000000             4
# 7   10083.900    252663296   0.023895      Read       1000000             4
# 8    2455.360    120165824   0.046673     Write       2500000             1
# 9    3624.450    120165824   0.031618      Read       2500000             1
# 10   4495.290    240331648   0.050986     Write       2500000             2
# 11   6669.120    240331648   0.034367      Read       2500000             2
# 12   6259.130    360497472   0.054927     Write       2500000             3
# 13   9061.540    360497472   0.037940      Read       2500000             3
# 14   7506.000    480663296   0.061071     Write       2500000             4
# 15  10407.100    480663296   0.044047      Read       2500000             4
# 16   2668.810    215165824   0.076887     Write       5000000             1
# 17   3656.220    215165824   0.056123      Read       5000000             1
# 18   4838.940    430331648   0.084811     Write       5000000             2
# 19   6622.600    430331648   0.061969      Read       5000000             2
# 20   6678.450    645497472   0.092176     Write       5000000             3
# 21   9153.230    645497472   0.067254      Read       5000000             3
# 22   7953.620    860663296   0.103197     Write       5000000             4
# 23  10368.300    860663296   0.079164      Read       5000000             4
# 24   2870.390    405165824   0.134615     Write      10000000             1
# 25   3619.340    405165824   0.106759      Read      10000000             1
# 26   5129.820    810331648   0.150647     Write      10000000             2
# 27   6374.110    810331648   0.121239      Read      10000000             2
# 28   7056.380   1215497472   0.164275     Write      10000000             3
# 29   9032.740   1215497472   0.128332      Read      10000000             3
# 30   8171.830   1620663296   0.189136     Write      10000000             4
# 31   9418.370   1620663296   0.164103      Read      10000000             4
# 32   3083.830    975165824   0.301570     Write      25000000             1
# 33   3647.520    975165824   0.254965      Read      25000000             1
# 34   5296.980   1950331648   0.351140     Write      25000000             2
# 35   6490.100   1950331648   0.286587      Read      25000000             2
# 36   4868.050   2925497472   0.573119     Write      25000000             3
# 37   8346.860   2925497472   0.334254      Read      25000000             3
# 38   2644.630   3900663296   1.406610     Write      25000000             4
# 39   9771.710   3900663296   0.380687      Read      25000000             4
# 40   2887.350   1925165824   0.635870     Write      50000000             1
# 41   3474.250   1925165824   0.528455      Read      50000000             1
# 42   1458.030   3850331648   2.518440     Write      50000000             2
# 43   6240.330   3850331648   0.588425      Read      50000000             2
# 44   1160.850   5775497472   4.744770     Write      50000000             3
# 45   7686.520   5775497472   0.716572      Read      50000000             3
# 46   1062.980   7700663296   6.908800     Write      50000000             4
# 47   1399.380   7700663296   5.248000      Read      50000000             4
# 48   1321.460   3825165824   2.760560     Write     100000000             1
# 49   3457.600   3825165824   1.055060      Read     100000000             1
# 50   1114.440   7650331648   6.546730     Write     100000000             2
# 51   1682.160   7650331648   4.337250      Read     100000000             2
# 52    965.936  11475497472  11.329800     Write     100000000             3
# 53    703.495  11475497472  15.556400      Read     100000000             3
# 54    788.419  15300663296  18.507700     Write     100000000             4
# 55    562.452  15300663296  25.943300      Read     100000000             4

# %%
df_read = df[df["ReadWrite"]=="Read"]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def autolabel(rects):
    for rect in rects:
        h = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.05*h, '%d'%int(h),
                ha='center', va='bottom')

# %%
read_write = ["Read", "Write"]
num_proc = [1,2,3,4]
num_part = [1000000, 2500000, 5000000, 10000000, 25000000, 50000000, 100000000]
width = 0.27
ind = np.arange(4)


for i in read_write:
    df1 = df_local[df_local["ReadWrite"]==i]
    df2 = df_volume[df_volume["ReadWrite"]==i]
    df3 = df_bind[df_bind["ReadWrite"]==i]
    
    for j in num_part:
        df11 = df1[df1["NumParticles"]==j]
        df22 = df2[df2["NumParticles"]==j]
        df33 = df3[df3["NumParticles"]==j]
        print("--------------------------------------------------------------------")
        print(i + "--" + str(j) + " particles")
        fig = plt.figure(figsize=(13, 6))
        ax = fig.add_subplot(111)
        xvals = []
        yvals = []
        zvals = []
        for k in num_proc:
            xvals.append(float(df11[df11["NumProcesses"]==k]["Bandwidth"]))
            yvals.append(float(df22[df22["NumProcesses"]==k]["Bandwidth"]))
            zvals.append(float(df33[df33["NumProcesses"]==k]["Bandwidth"]))
        
        rects1 = ax.bar(ind, xvals, width, color='r')
        rects2 = ax.bar([i+width for i in ind], yvals, width, color='g')
        rects3 = ax.bar([i+width*2 for i in ind], zvals, width, color='b')
        ax.set_xlabel("Number of MPI Processes")
        ax.set_ylabel("Bandwidth(MB/s)")
        ax.set_xticks([i+width for i in ind])
        ax.set_xticklabels((1,2,3,4))
        ax.legend((rects1[0], rects2[0], rects3[0]), ("local", "volumes", "bind_mount"))
        #autolabel(rects1)
        #autolabel(rects2)
        #autolabel(rects3)

        plt.show()
        print("--------------------------------------------------------------------")
# Out:
# --------------------------------------------------------------------
# Read--1000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Read--2500000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Read--5000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Read--10000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Read--25000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Read--50000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Read--100000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Write--1000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Write--2500000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Write--5000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Write--10000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Write--25000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Write--50000000 particles
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Write--100000000 particles
# --------------------------------------------------------------------
